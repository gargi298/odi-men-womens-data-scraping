# %% [markdown]
# # ODI CRICKET RATING MENS

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
player=[]

for i in Soup.find( 'div',class_=["rankings-block__banner--name"]):
    player.append(i.text)

player
# Out:
# ['Babar Azam']

# %%
players=[]
for i in Soup.find_all('td',class_=["table-body__cell name"]):
        players.append(i.text.replace('\n',''))
players
# Out:
# ['Virat Kohli',
#  'Ross Taylor',
#  'Rohit Sharma',
#  'Quinton de Kock',
#  'Jonny Bairstow',
#  'Aaron Finch',
#  'Rassie van der Dussen',
#  'David Warner',
#  'Imam-ul-Haq',
#  'Josh Hazlewood',
#  'Chris Woakes',
#  'Matt Henry',
#  'Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Shakib Al Hasan',
#  'Adam Zampa',
#  'Rashid Khan',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Ben Stokes',
#  'Mitchell Santner',
#  'Colin de Grandhomme',
#  'Imad Wasim',
#  'Mehedi Hasan',
#  'Jimmy Neesham',
#  'Virat Kohli',
#  'Ross Taylor',
#  'Rohit Sharma',
#  'Quinton de Kock',
#  'Jonny Bairstow',
#  'Aaron Finch',
#  'Rassie van der Dussen',
#  'David Warner',
#  'Imam-ul-Haq',
#  'Josh Hazlewood',
#  'Chris Woakes',
#  'Matt Henry',
#  'Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Shakib Al Hasan',
#  'Adam Zampa',
#  'Rashid Khan',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Ben Stokes',
#  'Mitchell Santner',
# ...

# %%
print(players[:10])
# Out:
# ['Virat Kohli', 'Quinton de Kock', 'Rohit Sharma', 'Aaron Finch', 'Rassie van der Dussen', 'Jonny Bairstow', 'David Warner', 'Fakhar Zaman', 'Joe Root', 'Josh Hazlewood']

# %%
team=[]
for i in Soup.find_all('span',class_=["table-body__logo-text"]):
    team.append(i.text)
team
# Out:
# ['IND',
#  'SA',
#  'IND',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'PAK',
#  'ENG',
#  'AUS',
#  'ENG',
#  'NZ',
#  'AFG',
#  'IND',
#  'BAN',
#  'SA',
#  'AUS',
#  'AFG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'ENG',
#  'PAK',
#  'BAN',
#  'NZ',
#  'IND',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'PAK',
#  'ENG',
#  'AUS',
#  'ENG',
#  'NZ',
#  'AFG',
#  'IND',
#  'BAN',
#  'SA',
#  'AUS',
#  'AFG',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'ENG',
#  'PAK',
#  'BAN',
#  'NZ',
#  'IND']

# %%
print(team[:10])
# Out:
# ['IND', 'SA', 'IND', 'AUS', 'SA', 'ENG', 'AUS', 'PAK', 'ENG', 'AUS']

# %%
rating=[]
for i in Soup.find_all('td',class_=["table-body__cell u-text-right rating"]):
    rating.append(i.text)
rating
# Out:
# ['811',
#  '796',
#  '791',
#  '779',
#  '776',
#  '775',
#  '762',
#  '741',
#  '740',
#  '709',
#  '700',
#  '691',
#  '681',
#  '679',
#  '664',
#  '658',
#  '652',
#  '650',
#  '295',
#  '282',
#  '276',
#  '268',
#  '266',
#  '256',
#  '235',
#  '226',
#  '224',
#  '811',
#  '796',
#  '791',
#  '779',
#  '776',
#  '775',
#  '762',
#  '741',
#  '740',
#  '709',
#  '700',
#  '691',
#  '681',
#  '679',
#  '664',
#  '658',
#  '652',
#  '650',
#  '295',
#  '282',
#  '276',
#  '268',
#  '266',
#  '256',
#  '235',
#  '226',
#  '224']

# %%
print(rating[:10])
# Out:
# ['811', '796', '791', '779', '776', '775', '762', '741', '740', '709']

# %% [markdown]
# # Blowers ranking

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" property="og:title"/>
# ...

# %%
name=[]
for i in Soup.find('div',class_=["rankings-block__banner--name-large"]):
    name.append(i.text)
name
# Out:
# ['Trent Boult']

# %%
names=[]
for i in Soup.find_all('td',class_=["table-body__cell rankings-table__name name"]):
    names.append(i.a.text)
names
# Out:
# ['Josh Hazlewood',
#  'Chris Woakes',
#  'Matt Henry',
#  'Mujeeb Ur Rahman',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Mitchell Starc',
#  'Rashid Khan',
#  'Andy McBrine',
#  'Pat Cummins',
#  'Shakib Al Hasan',
#  'Shaheen Afridi',
#  'Adam Zampa',
#  'Lungi Ngidi',
#  'Mustafizur Rahman',
#  'Yuzvendra Chahal',
#  'Mohammad Nabi',
#  'Tabraiz Shamsi',
#  'Mark Wood',
#  'Alzarri Joseph',
#  'Bhuvneshwar Kumar',
#  'Mitchell Santner',
#  'Akila Dananjaya',
#  'Mohammad Shami',
#  'Dushmantha Chameera',
#  'Ahmed Raza',
#  'Kuldeep Yadav',
#  'Ravindra Jadeja',
#  'Keshav Maharaj',
#  'Sheldon Cottrell',
#  'Wanindu Hasaranga',
#  'Mark Watt',
#  'Shadab Khan',
#  'Bilal Khan',
#  'David Willey',
#  'Simi Singh',
#  'Adil Rashid',
#  'Dwaine Pretorius',
#  'Imad Wasim',
#  'Blessing Muzarabani',
#  'Hasan Ali',
#  'Rohan Mustafa',
#  'M. Prasidh Krishna',
#  'Joshua Little',
#  'Andile Phehlukwayo',
#  'Taskin Ahmed',
#  'Craig Young',
#  'Tendai Chatara',
# ...

# %%
print(names[:10])
# Out:
# ['Josh Hazlewood', 'Chris Woakes', 'Matt Henry', 'Mujeeb Ur Rahman', 'Jasprit Bumrah', 'Mehedi Hasan', 'Kagiso Rabada', 'Mitchell Starc', 'Rashid Khan', 'Andy McBrine']

# %%
team=[]
for i in Soup.find('div',class_=["rankings-block__banner--nationality"]):
    team.append(i.text.replace('\n','',))
team
# Out:
# ['', '', '', '', 'NZ                    ']

# %%
teams=[]
for i in Soup.find_all('td',class_=["table-body__cell nationality-logo rankings-table__team"]):
    teams.append(i.text.replace('\n',' '))
teams
# Out:
# ['  AUS ',
#  '  ENG ',
#  '  NZ ',
#  '  AFG ',
#  '  IND ',
#  '  BAN ',
#  '  SA ',
#  '  AUS ',
#  '  AFG ',
#  '  IRE ',
#  '  AUS ',
#  '  BAN ',
#  '  PAK ',
#  '  AUS ',
#  '  SA ',
#  '  BAN ',
#  '  IND ',
#  '  AFG ',
#  '  SA ',
#  '  ENG ',
#  '  WI ',
#  '  IND ',
#  '  NZ ',
#  '  SL ',
#  '  IND ',
#  '  SL ',
#  '  UAE ',
#  '  IND ',
#  '  IND ',
#  '  SA ',
#  '  WI ',
#  '  SL ',
#  '  SCO ',
#  '  PAK ',
#  '  OMA ',
#  '  ENG ',
#  '  IRE ',
#  '  ENG ',
#  '  SA ',
#  '  PAK ',
#  '  ZIM ',
#  '  PAK ',
#  '  UAE ',
#  '  IND ',
#  '  IRE ',
#  '  SA ',
#  '  BAN ',
#  '  IRE ',
#  '  ZIM ',
#  '  WI ',
#  '  WI ',
#  '  NZ ',
#  '  BAN ',
#  '  SL ',
#  '  ENG ',
#  '  ENG ',
#  '  PAK ',
#  '  PAK ',
#  '  OMA ',
#  '  NEP ',
#  '  PNG ',
#  '  ENG ',
#  '  SCO ',
#  '  AUS ',
#  '  SL ',
#  '  OMA ',
#  '  USA ',
#  '  SA ',
#  '  ENG ',
#  '  UAE ',
#  '  SCO ',
#  '  ZIM ',
#  '  WI ',
#  '  ZIM ',
#  '  NED ',
#  '  SL ',
#  '  SA ',
#  '  IND ',
# ...

# %%
print(teams[0:10])
# Out:
# ['  AUS ', '  ENG ', '  NZ ', '  AFG ', '  IND ', '  BAN ', '  SA ', '  AUS ', '  AFG ', '  IRE ']

# %%
rating=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--rating"]):
    rating.append(i.text)
rating
# Out:
# ['737']

# %%
ratings=[]
for i in Soup.find_all('td',class_=["table-body__cell rating"]):
    ratings.append(i.text)
ratings
# Out:
# ['709',
#  '700',
#  '691',
#  '681',
#  '679',
#  '664',
#  '658',
#  '652',
#  '650',
#  '646',
#  '636',
#  '636',
#  '630',
#  '625',
#  '615',
#  '611',
#  '610',
#  '603',
#  '597',
#  '594',
#  '593',
#  '585',
#  '583',
#  '574',
#  '549',
#  '540',
#  '539',
#  '538',
#  '534',
#  '533',
#  '525',
#  '523',
#  '519',
#  '517',
#  '504',
#  '501',
#  '499',
#  '497',
#  '492',
#  '488',
#  '484',
#  '483',
#  '483',
#  '481',
#  '480',
#  '473',
#  '471',
#  '470',
#  '466',
#  '460',
#  '458',
#  '458',
#  '456',
#  '455',
#  '454',
#  '449',
#  '447',
#  '445',
#  '445',
#  '443',
#  '437',
#  '436',
#  '436',
#  '436',
#  '429',
#  '421',
#  '419',
#  '419',
#  '410',
#  '409',
#  '408',
#  '406',
#  '401',
#  '401',
#  '395',
#  '395',
#  '394',
#  '393',
#  '390',
#  '390',
#  '382',
#  '382',
#  '381',
#  '380',
#  '379',
#  '377',
#  '374',
#  '374',
#  '374',
#  '372',
#  '370',
#  '365',
#  '365',
#  '364',
#  '362',
#  '357',
#  '356',
#  '356',
#  '355']

# %%
print(ratings[0:10])
# Out:
# ['709', '700', '691', '681', '679', '664', '658', '652', '650', '646']

# %% [markdown]
# # TOP 10 TEAMS

# %%
top_team=[]
for i in Soup.find_all('td',class_=["rankings-block__banner--team-name"]):
    
    team.append(i.text)
team
# Out:
# []

# %% [markdown]
# # Womens odi teams

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
Top_team=[]
for i in Soup.find_all('tr',class_=["rankings-block__banner"]):
    Top_team.append(i.text.replace('\n',' '))
Top_team
# Out:
# [' 1   Australia AUS  28 4,663                              167                                ']

# %%
topteams=[]
for i in Soup.find_all('td',class_=["table-body__cell rankings-table__team"]):
    topteams.append(i.text.replace('\n',''))
topteams
# Out:
# ['South AfricaSA',
#  'EnglandENG',
#  'IndiaIND',
#  'New ZealandNZ',
#  'West IndiesWI',
#  'BangladeshBAN',
#  'PakistanPAK',
#  'IrelandIRE',
#  'Sri LankaSL',
#  'ZimbabweZIM']

# %%
Matches=[]
for i in Soup.find_all('td',class_=["table-body__cell u-center-text"]):
    Matches.append(i.text)
Matches
# Out:
# ['28',
#  '3,504',
#  '29',
#  '3,425',
#  '29',
#  '2,890',
#  '31',
#  '3,018',
#  '28',
#  '2,478',
#  '12',
#  '935',
#  '26',
#  '1,753',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
points=[]
for i in Soup.find_all('td',class_=["table-body__cell u-center-text"]):
    points.append(i.text)
points
# Out:
# ['28',
#  '3,504',
#  '29',
#  '3,425',
#  '29',
#  '2,890',
#  '31',
#  '3,018',
#  '28',
#  '2,478',
#  '12',
#  '935',
#  '26',
#  '1,753',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
ratings=[]
for i in Soup.find_all('td',class_=["table-body__cell u-text-right rating"]):
    ratings.append(i.text)
ratings
# Out:
# ['125', '118', '100', '97', '89', '78', '67', '48', '47', '0']

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
batting_player=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--name-large"]):
    batting_player.append(i.text)
batting_player
# Out:
# ['Laura Wolvaardt']

# %%
batting_players=[]
for i in Soup.find_all('td',class_=["table-body__cell rankings-table__name name"]):
    batting_players.append(i.text.replace('\n',''))
batting_players
# Out:
# ['Beth Mooney',
#  'Meg Lanning',
#  'Natalie Sciver',
#  'Alyssa Healy',
#  'Mithali Raj',
#  'Rachael Haynes',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Ellyse Perry',
#  'Heather Knight',
#  'Deandra Dottin',
#  'Lizelle Lee',
#  'Stafanie Taylor',
#  'Harmanpreet Kaur',
#  'Amelia Kerr',
#  'Sophie Devine',
#  'Mignon du Preez',
#  'Suzie Bates',
#  'Hayley Matthews',
#  'Marizanne Kapp',
#  'Ashleigh Gardner',
#  'Sune Luus',
#  'Bismah Maroof',
#  'Amy Jones',
#  'Maddie Green',
#  'Deepti Sharma',
#  'Fargana Hoque',
#  'Chloe-Lesleigh Tryon',
#  'Aliya Riaz',
#  'Danielle Wyatt',
#  'Tahlia McGrath',
#  'Gaby Lewis',
#  'Nahida Khan',
#  'Poonam Raut',
#  'Nida Dar',
#  'Katey Martin',
#  'Yastika Bhatia',
#  'Sophia Dunkley',
#  'Katherine Brunt',
#  'Laura Delany',
#  'Dane van Niekerk',
#  'Javeria Khan',
#  'Shemaine Campbelle',
#  'Rumana Ahmed',
#  'Shafali Verma',
#  'Umaima Sohail',
#  'Brooke Halliday',
#  'Richa Ghosh',
# ...

# %%
print(batting_players[:10])
# Out:
# ['Beth Mooney', 'Meg Lanning', 'Natalie Sciver', 'Alyssa Healy', 'Mithali Raj', 'Rachael Haynes', 'Tammy Beaumont', 'Amy Satterthwaite', 'Smriti Mandhana', 'Ellyse Perry']

# %%
team_women=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--nationality"]):
    team_women.append(i.text.replace('\n',''))
team_women
# Out:
# ['SA                    ']

# %%
team_womens=[]
for i in Soup.find_all('td',class_=["table-body__cell nationality-logo rankings-table__team"]):
    team_womens.append(i.text.replace('\n',''))
team_womens
# Out:
# ['AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'IND',
#  'AUS',
#  'ENG',
#  'NZ',
#  'IND',
#  'AUS',
#  'ENG',
#  'WI',
#  'SA',
#  'WI',
#  'IND',
#  'NZ',
#  'NZ',
#  'SA',
#  'NZ',
#  'WI',
#  'SA',
#  'AUS',
#  'SA',
#  'PAK',
#  'ENG',
#  'NZ',
#  'IND',
#  'BAN',
#  'SA',
#  'PAK',
#  'ENG',
#  'AUS',
#  'IRE',
#  'PAK',
#  'IND',
#  'PAK',
#  'NZ',
#  'IND',
#  'ENG',
#  'ENG',
#  'IRE',
#  'SA',
#  'PAK',
#  'WI',
#  'BAN',
#  'IND',
#  'PAK',
#  'NZ',
#  'IND',
#  'ENG',
#  'AUS',
#  'PAK',
#  'BAN',
#  'IND',
#  'BAN',
#  'SA',
#  'WI',
#  'PAK',
#  'BAN',
#  'IRE',
#  'IND',
#  'BAN',
#  'NZ',
#  'NZ',
#  'AUS',
#  'WI',
#  'SA',
#  'BAN',
#  'ENG',
#  'BAN',
#  'IRE',
#  'SA',
#  'ZIM',
#  'IND',
#  'AUS',
#  'ENG',
#  'NZ',
#  'BAN',
#  'IRE',
#  'WI',
#  'IND',
#  'ZIM',
#  'IND',
#  'IRE',
#  'IND',
#  'NZ',
#  'IND',
#  'SA',
#  'NZ',
#  'IND',
#  'IRE',
#  'ENG',
#  'PAK',
#  'PAK',
#  'AUS',
#  'IRE',
#  'IND',
#  'ZIM',
#  'AUS']

# %%
print(team_womens[:10])
# Out:
# ['AUS', 'AUS', 'ENG', 'AUS', 'IND', 'AUS', 'ENG', 'NZ', 'IND', 'AUS']

# %%
women_team_rating=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--rating"]):
    women_team_rating.append(i.text)
women_team_rating
# Out:
# ['740']

# %%
womens_team_rating=[]
for i in Soup.find_all('td',class_=["table-body__cell rating"]):
    womens_team_rating.append(i.text)
womens_team_rating
# Out:
# ['726',
#  '718',
#  '705',
#  '703',
#  '686',
#  '684',
#  '682',
#  '681',
#  '669',
#  '649',
#  '624',
#  '619',
#  '608',
#  '604',
#  '602',
#  '597',
#  '591',
#  '578',
#  '568',
#  '547',
#  '544',
#  '521',
#  '508',
#  '484',
#  '477',
#  '474',
#  '471',
#  '468',
#  '456',
#  '450',
#  '440',
#  '437',
#  '436',
#  '434',
#  '421',
#  '420',
#  '420',
#  '407',
#  '400',
#  '399',
#  '392',
#  '392',
#  '392',
#  '391',
#  '382',
#  '378',
#  '376',
#  '346',
#  '346',
#  '344',
#  '339',
#  '333',
#  '330',
#  '328',
#  '326',
#  '324',
#  '323',
#  '322',
#  '321',
#  '318',
#  '304',
#  '297',
#  '294',
#  '293',
#  '282',
#  '274',
#  '272',
#  '252',
#  '250',
#  '248',
#  '248',
#  '243',
#  '242',
#  '242',
#  '240',
#  '239',
#  '238',
#  '229',
#  '228',
#  '228',
#  '223',
#  '221',
#  '217',
#  '217',
#  '216',
#  '213',
#  '212',
#  '212',
#  '212',
#  '209',
#  '207',
#  '203',
#  '198',
#  '197',
#  '194',
#  '193',
#  '191',
#  '191',
#  '191']

# %%
print(womens_team_rating[:10])
# Out:
# ['726', '718', '705', '703', '686', '684', '682', '681', '669', '649']

# %% [markdown]
# top 10 odi womens all rounder

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" property="og:title"/>
# ...

# %%
allrounder_player=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--name-large"]):
    allrounder_player.append(i.text)
allrounder_player
# Out:
# ['Ellyse Perry']

# %%
allrounder_players=[]
for i in Soup.find_all('td',class_=["table-body__cell rankings-table__name name"]):
    allrounder_players.append(i.text.replace('\n',''))
allrounder_players
# Out:
# ['Natalie Sciver',
#  'Marizanne Kapp',
#  'Hayley Matthews',
#  'Amelia Kerr',
#  'Ashleigh Gardner',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Katherine Brunt',
#  'Jhulan Goswami',
#  'Stafanie Taylor',
#  'Nida Dar',
#  'Sophie Devine',
#  'Sophie Ecclestone',
#  'Sune Luus',
#  'Heather Knight',
#  'Dane van Niekerk',
#  'Rumana Ahmed',
#  'Salma Khatun',
#  'Chloe-Lesleigh Tryon']

# %%
print(allrounder_players[:10])
# Out:
# ['Natalie Sciver', 'Marizanne Kapp', 'Hayley Matthews', 'Amelia Kerr', 'Ashleigh Gardner', 'Deepti Sharma', 'Jess Jonassen', 'Katherine Brunt', 'Jhulan Goswami', 'Stafanie Taylor']

# %%
team=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--nationality"]):
    team.append(i.text.replace('\n',''))
    
team
# Out:
# ['AUS                    ']

# %%
team_allrounder=[]
for i in Soup.find_all('td',class_=["table-body__cell nationality-logo rankings-table__team"]):
    team_allrounder.append(i.text.replace('\n',''))
team_allrounder
# Out:
# ['ENG',
#  'SA',
#  'WI',
#  'NZ',
#  'AUS',
#  'IND',
#  'AUS',
#  'ENG',
#  'IND',
#  'WI',
#  'PAK',
#  'NZ',
#  'ENG',
#  'SA',
#  'ENG',
#  'SA',
#  'BAN',
#  'BAN',
#  'SA']

# %%
print(team_allrounder[:10])
# Out:
# ['ENG', 'SA', 'WI', 'NZ', 'AUS', 'IND', 'AUS', 'ENG', 'IND', 'WI']

# %%
rating_allrounder=[]
for i in Soup.find_all('div',class_=["rankings-block__banner--rating"]):
    rating_allrounder.append(i.text)
rating_allrounder
# Out:
# ['404']

# %%
ratings_allrounder=[]
for i in Soup.find_all('td',class_=["table-body__cell rating"]):
    ratings_allrounder.append(i.text)
ratings_allrounder
# Out:
# ['376',
#  '359',
#  '340',
#  '335',
#  '278',
#  '249',
#  '246',
#  '239',
#  '217',
#  '208',
#  '204',
#  '202',
#  '196',
#  '196',
#  '179',
#  '176',
#  '169',
#  '167',
#  '161']

# %%
print(ratings_allrounder[:10])
# Out:
# ['376', '359', '340', '335', '278', '249', '246', '239', '217', '208']
